# %%
# Breaking the records
n_game=(int,input().split())
scores=list(map(int,input().split()))

min_scores=0
max_scores=0
equal=0
min_reference=scores[0]
max_reference=scores[0]

for i in range(1, len(scores)):
    if scores[i] > max_reference:
        max_reference = scores[i]
        max_scores+=1
        # print("New reference:", reference)

    elif scores[i]<min_reference:
        min_reference=scores[i]
        min_scores+=1
print(max_scores,min_scores)
# Out:
#  10
#  3 4 21 36 10 28 35 5 24 42
# 4 0

# %%
10
3 4 21 36 10 28 35 5 24 42
