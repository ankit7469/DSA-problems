# %%
# Number line jump 
x1,v1,x2,v2=map(int,input().split())     #x1, x2= starting points for both kangaroos and v1 and v2 are the jump distance

# For kangaro 1
kangaroo_1= (x1+v1)

# For kangaroo 2

kangaroo_2=(x2+v2)

if(v1<=v2):
    print("NO")
elif(kangaroo_1==kangaroo_2):
    print("YES")
else:
    print("NO")
# Out:
#  14 4 98 2
# NO

# %%
0 3 4 2
0 2 5 3
