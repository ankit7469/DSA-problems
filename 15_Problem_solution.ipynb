# %%
# Electronic shop --

k=list(map(int,input().split()))      # Budget
m=list(map(int,input().split()))      # Keyboard prices
n=list(map(int,input().split()))      # USB price
overall_max=-1
for u in range(len(k)):
    max_sum=-1
    for i in range(len(m)):
        for j in range(len(n)):
            if i+j<=u:
                max_sum=max(max_sum,i+j)
        overall_max=max(overall_max,max_sum)
print(overall_max)
# Out:
#  10 2 3
#  3 1
#  5 2 8
# 1

# %% [markdown]
# # 10 2 3
# 3 1
# 5 2 8
# Sample Output 0
#
# 9

# %%
# Electronic Shop - print only overall max

k = list(map(int, input().split()))   # budgets
m = list(map(int, input().split()))   # keyboard prices
n = list(map(int, input().split()))   # USB prices

overall_max = -1

for u in k:
    max_sum = -1
    for i in m:
        for j in n:
            if i + j <= u:
                max_sum = max(max_sum, i + j)
    overall_max = max(overall_max, max_sum)

print(overall_max)
# Out:
#  5 1 1
#  4
#  5
# -1
