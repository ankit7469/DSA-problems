# %%
# Migratory birds

n=map(int,input().split())
arr=list(map(int,input().split()))

freq = {}

for x in arr:
    if x in freq:
        freq[x] += 1
    else:
        freq[x] = 1

max_element = None
max_count = 0

for key, value in freq.items():
    if value > max_count:
        max_count = value
        max_element = key
        if freq > max_freq:
    update
elif freq == max_freq and id < current_answer:
    update


print(max_element)
# Out:
#  11
#  1 2 3 4 5 4 3 2 1 3 4
# 3
